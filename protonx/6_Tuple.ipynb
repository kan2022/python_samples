# %%
fruits = ['banana', 'dragon fruit', 'watermelon']

# %%
fruits = ('banana', 'dragon fruit', 'watermelon')

# %%
fruits[0]
# Out:
# 'banana'

# %%
fruits[1:]
# Out:
# ('dragon fruit', 'watermelon')

# %% [markdown]
# https://www.w3schools.com/python/python_tuples_methods.asp$0
